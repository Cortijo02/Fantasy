# %%
import pandas as pd
import seaborn as sn

from matplotlib import pyplot as plt

# %%
participante         = ["Juan Carlos", "Fran", "AndresPB8", "juamonchi", "Roberto", "Cortijo", "RulilloElPillo", "Adri4K_Mister", "_.jorgeortiz._", "pablito"]

goles                = [14,25,16,13,9,7,11,8,12,7]

#Desactualizado
jugador_azul         = [13,21,14,11,11,7,7,7,8,9]

expulsiones          = [2,0,0,0,0,0,2,0,0,0]
puntuacion_negativa  = [18,0,2,7,2,3,12,5,6,4]
jugadores_negativos  = [18,0,2,3,2,3,12,1,2,0]
n_jornadas           = [8,8,8,8,8,8,8,8,8,5]
jugadores_grises     = [8,5,9,8,4,10,11,12,12,8]
puntos               = [586,704,577,552,404,555,495,473,349,339]

df = pd.DataFrame(columns=["Posicion", "Participante", "Puntos", "Número_de_goles", "Número_de_Jugadores_en_Azul", "Expulsiones", "Número_de_Jornadas", "Jugadores_Grises",
                           "Puntuacion_Negativa", "Jugadores_Negativos"])

df.Participante = participante
df.Puntos = puntos
df.Número_de_goles = goles
df.Número_de_Jugadores_en_Azul = jugador_azul
df.Expulsiones = expulsiones
df.Número_de_Jornadas = n_jornadas
df.Jugadores_Grises = jugadores_grises
df.Puntuacion_Negativa = puntuacion_negativa
df.Jugadores_Negativos = jugadores_negativos
df.index = participante

df = df.sort_values(by=['Puntos'], ascending=False)

df.Posicion = ["Primero", "Segundo", "Tercero", "Cuarto", "Quinto", "Sexto", "Septimo", "Octavo", "Noveno", "Decimo"]
df
# Out:
#                Posicion    Participante  Puntos  Número_de_goles  \
# Fran            Primero            Fran     704               25
# Juan Carlos     Segundo     Juan Carlos     586               14
# AndresPB8       Tercero       AndresPB8     577               16
# Cortijo          Cuarto         Cortijo     555                7
# juamonchi        Quinto       juamonchi     552               13
# RulilloElPillo    Sexto  RulilloElPillo     495               11
# Adri4K_Mister   Septimo   Adri4K_Mister     473                8
# Roberto          Octavo         Roberto     404                9
# _.jorgeortiz._   Noveno  _.jorgeortiz._     349               12
# pablito          Decimo         pablito     339                7
#
#                 Número_de_Jugadores_en_Azul  Expulsiones  Número_de_Jornadas  \
# Fran                                     21            0                   8
# Juan Carlos                              13            2                   8
# AndresPB8                                14            0                   8
# Cortijo                                   7            0                   8
# juamonchi                                11            0                   8
# RulilloElPillo                            7            2                   8
# Adri4K_Mister                             7            0                   8
# Roberto                                  11            0                   8
# _.jorgeortiz._                            8            0                   8
# pablito                                   9            0                   5
#
#                 Jugadores_Grises  Puntuacion_Negativa  Jugadores_Negativos
# Fran                           5                    0                    0
# Juan Carlos                    8                   18                   18
# AndresPB8                      9                    2                    2
# Cortijo                       10                    3                    3
# juamonchi                      8                    7                    3
# RulilloElPillo                11                   12                   12
# Adri4K_Mister                 12                    5                    1
# Roberto                        4                    2                    2
# _.jorgeortiz._                12                    6                    2
# pablito                        8                    4                    0

# %%
pieplot = df.plot.pie(y= "Puntuacion_Negativa", figsize = (15,15), legend = True)
# Out:
# /Users/corti/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:677: UserWarning: The handle <matplotlib.patches.Wedge object at 0x7f9be99c8b50> has a label of '_.jorgeortiz._' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %%
fig, ax = plt.subplots(figsize = (15, 15))

sns_plot = sn.barplot(data=df, x="Participante", y="Jugadores_Negativos")
fig = sns_plot.get_figure()
fig.savefig("output.png")

# %%
fig, ax = plt.subplots(figsize = (15, 15))

sns_plot = sn.barplot(data=df, x="Participante", y="Puntos")
fig = sns_plot.get_figure()
#fig.savefig("output.png")

# %%
fig, ax = plt.subplots(figsize = (15, 15))

sns_plot = sn.barplot(data=df, x="Participante", y="Número_de_goles")
fig = sns_plot.get_figure()
fig.savefig("output.png")

# %%
fig, ax = plt.subplots(figsize = (15, 15))

sns_plot = sn.barplot(data=df, x="Participante", y="Número_de_Jugadores_en_Azul")
fig = sns_plot.get_figure()
fig.savefig("output.png")

# %%
fig, ax = plt.subplots(figsize = (15, 15))

sns_plot = sn.barplot(data=df, x="Participante", y="Jugadores_Grises")
fig = sns_plot.get_figure()
fig.savefig("output.png")
